# %% [markdown]
# The first step is to import some helper functions I've written. One is to display the particles that are produced in these collisions, and the other is to get the collisions data out of the files.

# %%
from draw_objects3D import *
from cms_tools import get_collisions

# %% [markdown]
# Open the file and pull out the collision data. This returns a Python list of all the collisions in that file. You can use these data to visualize individual collisions or to perform a data analysis on <i>all</i> the collisions.

# %%
f = open('small_test_file.dat')
collisions = get_collisions(f)

# %% [markdown]
# Let's take a look at some of these collisions!

# %%
display_collision3D(collisions[0])

# %%
display_collision3D(collisions[3])

# %%
display_collision3D(collisions[5])

# %% [markdown]
# Let's see what we're looking at.
#
# * The red lines represent the protons colliding.
# * The other lines represent particles created in the collisions. The length of these lines tell us how much momentum (or energy) they have. The colors are different particles/object.
#     * Blue - <a href="http://en.wikipedia.org/wiki/Muon">muons</a>
#      * Orange - jets
#      * Green - electrons
#      * Gray - photons
